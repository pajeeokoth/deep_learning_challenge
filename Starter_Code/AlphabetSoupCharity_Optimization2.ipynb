# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = application_df.copy()
df = df.drop(columns=['EIN', 'NAME'], axis=1)
df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T2','T4','T6','T5','T7','T8','T9','T10','T13','T12','T25','T14','T29','T15','T17','T19']

# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     7262
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
list = ['C2190', 'C4200','C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820', 'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245',
                 'C2500', 'C1570', 'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561', 'C4500', 'C2150']
df.drop(df[df.CLASSIFICATION.isin(list)].index, inplace=True)
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C4100        6
# C1720        6
# C2400        6
# C1600        5
# C1257        5
# C1260        3
# C2710        3
# C0           3
# C1267        2
# C1256        2
# C1234        2
# C1246        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C7000','C1700','C4000','C5000','C1270','C2700','C2800','C7100','C1300','C1280','C1230','C1400','C7200','C2300','C1240',
                             'C8000','C7120','C1500','C1800','C6000','C1250','C8200','C1238','C1278','C1237','C1235','C7210','C4100','C1720','C2400',
                             'C1600','C1257','C1260','C2710','C0','C1267','C1256','C1234','C1246','C3200','C2000','C1200','C3000','C2100']

# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# Other    16947
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of incomes to be replaced
# use the variable name `incomes_to_replace`
incomes_to_replace = ['1-9999','10000-24999','25000-99999','100000-499999','1M-5M','5M-10M','10M-50M','50M+']

# Replace in dataframe
for amt in incomes_to_replace:
    df['INCOME_AMT'] = df['INCOME_AMT'].replace(amt,"income")

# Check to make sure binning was successful
df['INCOME_AMT'].value_counts()
# Out:
# 0         24370
# income     9903
# Name: INCOME_AMT, dtype: int64

# %%
# Choose a cutoff value and create a list of affiliations to be replaced
# use the variable name `incomes_to_replace`
affiliation_to_replace = ['CompanySponsored','Family/Parent','National','Regional','Other']

# Replace in dataframe
for affls in affiliation_to_replace:
    df['AFFILIATION'] = df['AFFILIATION'].replace(affls,"others")

# Check to make sure binning was successful
df['AFFILIATION'].value_counts()
# Out:
# Independent    18454
# others         15819
# Name: AFFILIATION, dtype: int64

# %%
# Choose a cutoff value and create a list of use_case to be replaced
# use the variable name `incomes_to_replace`
usage_to_replace = ['ProductDev','CommunityServ','Heathcare','Other']

# Replace in dataframe
for usg in usage_to_replace:
    df['USE_CASE'] = df['USE_CASE'].replace(usg,"others")

# Check to make sure binning was successful
df['USE_CASE'].value_counts()
# Out:
# Preservation    28069
# others           6204
# Name: USE_CASE, dtype: int64

# %%
# Choose a cutoff value and create a list of organizations to be replaced
# use the variable name `incomes_to_replace`
org_to_replace = ['Association','Co-operative','Corporation']

# Replace in dataframe
for organ in org_to_replace:
    df['ORGANIZATION'] = df['ORGANIZATION'].replace(organ,"others")

# Check to make sure binning was successful
df['ORGANIZATION'].value_counts()
# Out:
# Trust     23492
# others    10781
# Name: ORGANIZATION, dtype: int64

# %%
# Drop the sue_case and income_amt columns as they seem to contain extreme values.
df = df.drop(columns=['USE_CASE','INCOME_AMT'], axis=1)

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummy = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION',
         'ORGANIZATION', 'SPECIAL_CONSIDERATIONS']
df_dummies = pd.get_dummies(df, columns=dummy)

df_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       1
# 1       1   108590              1                       0
# 2       1     5000              0                       1
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T3  AFFILIATION_Independent  AFFILIATION_others  \
# 0                    0                        1                   0
# 1                    1                        1                   0
# 2                    0                        0                   1
# 3                    1                        0                   1
# 4                    1                        1                   0
#
#    CLASSIFICATION_C1000  CLASSIFICATION_Other  ORGANIZATION_Trust  \
# 0                     1                     0                   0
# 1                     0                     1                   0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = df_dummies['IS_SUCCESSFUL'].values
X = df_dummies.drop(['IS_SUCCESSFUL'],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-15-0d6a80d7b85c>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = df_dummies.drop(['IS_SUCCESSFUL'],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  20
hidden_nodes_layer2 = 10
hidden_nodes_layer3 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 20)                260
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  dense_3 (Dense)             (None, 1)                 6
#
# ...
# Total params: 531
# Trainable params: 531
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 8s 5ms/step - loss: 0.6152 - accuracy: 0.6858
# Epoch 2/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.6102 - accuracy: 0.6876
# Epoch 3/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.6091 - accuracy: 0.6885
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6090 - accuracy: 0.6930
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6089 - accuracy: 0.6921
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6084 - accuracy: 0.6945
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6081 - accuracy: 0.6940
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6082 - accuracy: 0.6939
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6077 - accuracy: 0.6942
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.6009 - accuracy: 0.6986 - 724ms/epoch - 3ms/step
# Loss: 0.6009496450424194, Accuracy: 0.6985645890235901

# %%
# Export our model to HDF5 file
nn.save('/content/drive/MyDrive/notebooks/AlphabetSoupCharity_Optimization2.h5')
nn.save_weights("/content/drive/MyDrive/notebooks/model_weights2.h5")
